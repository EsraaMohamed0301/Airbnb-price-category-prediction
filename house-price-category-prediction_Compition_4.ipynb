# %% [markdown]
# # **Question**

# %% [markdown]
# **Q1) Is fully-connected model a good one for sequential data? Why? How about for image data? Is it good? Why?**
# > * **Is fully-connected model a good one for sequential data? Why?**
#     * No, Recurrent neural network works best for sequential data.
#     * **RNNs** are an excellent choice for modeling sequential data such as text because they use an internal state to process the sequence. Having an internal state/memory of how the inputs are related to one another is crucial for modeling the data effectively. RNN’s can remember important things about the input they received, which allows them to be very precise in predicting what’s coming next. This is why they're the preferred algorithm for sequential data like time series, speech, text, financial data, audio, video, weather and much more.
#     * A **fully connected** layer each neuron is connected to every neuron in the previous layer, and each connection has it's own weight. This is a totally general purpose connection pattern and makes no assumptions about the features in the data. It's also very expensive in terms of memory (weights) and computation (connections).
# * **How about for image data? Is it good? Why?**
#   * No, Becuase The number of parameters in a neural network grows rapidly with the increase in the number of layers. This can make training for a model computationally heavy (and sometimes not feasible). Tuning so many of parameters can be a very huge task face several problems, for e.g. slower training time, chances of overfitting e.t.c. The time taken for tuning these parameters is diminished by CNNs. So, Convolutional neural network works best for image data.
#   * **CNNs** are trained to identify and extract the best features from the images for the problem at hand. CNNs are very effective in reducing the number of parameters without losing on the quality of models. The main functional difference of convolution neural network is that, the main image matrix is reduced to a matrix of lower dimension in the first layer.
#   * We use a fully connected architecture rather than a convolutional architecture, as this is not an image classification task and a simpler model seems justified.
#   * Fully connected neural networks are good enough classifiers, however they aren't good for feature extraction.

# %% [markdown]
# **Q2) What is gradient vanishing and gradient explosion, and how GRU/LSTM tries to mitigate this problem?**
# > * **What is gradient vanishing and gradient explosion?**
#     * **Vanishing gradient:** is a common problem in deep learning, which is not properly designed. Vanishing gradient problem arises if the gradient tends to get smaller as we are conducting backpropagation. It implies that neurons are learning so slow that optimization grind to a halt.(you're multiplying a bunch of numbers together and these numbers tend to get smaller and smaller. So they tend to disappear and what it's trying.). The network will just stop learning and freeze.
#     * **Exploding gradient:** occurs when small changes in the backpropagation result in huge updates in the weights during optimization process. The network will start to generally overpredict.
# * **How GRU/LSTM tries to mitigate this problem?**
#   * **LSTMs solve the vanishing gradient problem** using a unique additive gradient structure that includes direct access to the forget gate’s activations, enabling the network to encourage desired behaviour from the error gradient using frequent gates update on every time step of the learning process.
#   * the backpropagated gradient neither vanishes or explodes when passing through, but remains constant.
#   * both GRUs and LSTMs help solve the problem that was first encountered when RNNs were used, namely exploding and vanishing gradients. Because of the recurrent application of the same parameters, it was often the case that gradients would quickly go to zero (not helpful) or to infinity (also not helpful), meaning that backpropagation was difficult or even impossible as the recurrent network was unrolled. This problem was addressed with GRU and LSTM because these tend to keep inputs and outputs from the cell in tractable value ranges. This is due both to the form of the activation function they use and to the way that the update gate can learn to pass information through or not, leading to reasonable gradient values being much more likely than in a vanilla RNN cell, which has no notion of a gate.
#   * There are two factors that affect the magnitude of gradients - the weights and the activation functions (or more precisely, their derivatives) that the gradient passes through

# %% [markdown]
# **Q3) What is multi-objective/multi-task learning? What is multi-modality learning? How do you use them in this assignment?**
# > * **What is multi-task learning?**
#     * it aims to solve multiple different tasks at the same time, by taking advantage of the similarities between different tasks. This can improve the learning efficiency and also act as a regularizer.
#     * Such approaches offer advantages like improved data efficiency, reduced overfitting through shared representations, and fast learning by leveraging auxiliary information.
# * **What is multi-modality learning?**
#     * The world surrounding us involves multiple modalities – we see objects, hear sounds, feel texture, smell odors, and so on. In general terms, a modality refers to the way in which something happens or is experienced. Multi-Modality learning leverages the information from different source of information to make informed predictions.
#     * Multimodal learning helps to understand and analyze better when various senses are engaged in the processing of information.
#     * multiple types of modalities are image, video, text, audio, body gestures, facial expressions, and physiological signals.
# * **How do you use them in this assignment?**
#   * I use the multi-task and multi-modality learning in this notebook.
#   * multi-modality learning (inputs):
#       * Summary of areas (text).
#       * Image of areas (image).
#   * multi-tasks learning (outputs):
#       * Different areas Types (text).
#       * Price of areas (number)

# %% [markdown]
# **Q4) What is the difference among xgboost, lightgbm and catboost?**
# > * LightGBM can sometimes outperform XGBoost, but not always. However, LightGBM is about 7 times faster than XGBoost!
# * XGBoost has slightly outperformed CatBoost. However, CatBoost is about 3.5 times faster than XGBoost!
# * LightGBM has slightly outperformed CatBoost and it is about 2 times faster than CatBoost!
# * When we consider execution time, LightGBM wins hands down! It is 7 times faster than XGBoost and 2 times faster than CatBoost.
# * When we consider performance, XGBoost is slightly better than the other two.
# * When we consider both performance and execution time together, LightGBM is the best option.
# * The dataset has categorical features, consider using LightGBM or CatBoost. Both can handle categorical features that are not already encoded. CatBoost is the best option to deal with categorical features. XGBoost cannot handle categorical features by itself, it only accepts numerical values.
# * XGBoost has some more generalization capabilities than other boosting techniques. In performance-wise, it is good.
# * In XGBoost, trees grow depth-wise while in LightGBM, trees grow leaf-wise.

# %% [markdown]
# ![1_A0b_ahXOrrijazzJengwYw.png](data:image/png;base64,...)

# %% [markdown]
# # **Problem Formulation**

# %% [markdown]
# ## **Define the problem**

# %% [markdown]
# One of the biggest problems when people prepare to post a new listing on airbnb is, how much should one ask for? Of course the most intuitive way is to check how other similar postings price their apartment/house. we are going to predict the listing price based on the listing characteristic

# %% [markdown]
# ## **What is the input?**

# %% [markdown]
# * The dataset contains listings of different areas in Montreal during 2019.
# * The inputs data:
#   * Summary: is text. it details and describe the different areas.
#   * Image: is image about the different areas.

# %% [markdown]
# ## **What is the output?**

# %% [markdown]
# * The outputs data:
#   * Type: is a text.
#   * Price: we define three categories: beginner, plus, premium based on the created listing. Respectively we use 0, 1, 2 to denote these three categories.

# %% [markdown]
# ## **What data mining function is required?**

# %% [markdown]
# In this case, it will be Multi Classification methods for such models.

# %% [markdown]
# ## **What could be the challenges?**

# %% [markdown]
# * The data contains different languages.
# * The data contains various forms of words.
# * we are going to predict the listing price based on the listing characteristics(Multi-modality).

# %% [markdown]
# ## **What is the impact?**

# %% [markdown]
# A pricing range to the new host rather than a fix price. it will be very useful to predict the price and the type of areas by details and image of area.

# %% [markdown]
# ## **What is an ideal solution?**

# %% [markdown]
# According to my subsequent attempts, Convolutional Layer with Embedding layer, Multi-modality and Multi-task. is the best approach because it provides me the highest kaggle score.
#
#      In Kaggle
#         * Public score: 0.69456
#         * Private score: 0.67201
#
#
#
# The Convolutional layer creates a convolution kernel that is wind with layers input which helps produce a tensor of outputs.

# %% [markdown]
# ## **What is the experimental protocol used and how was it carried out?**

# %% [markdown]
# I will split the data to use Holdout method is split the training dataset to training data and validation data

# %% [markdown]
# ## **How did we tune hyper-parameters in the template?**

# %% [markdown]
# In the template, I will tune hyperparameters by changing the values of:
# * Epochs
# * batch_size
# * patience in Early Stopping
# * loss of weight to type
# * loss of weight to price
# * number of kernal channel
# * number of filter
# * number of Strides
# * number of padding
# * Activation function
# * values of regularizer(l1, l2)
# * resize of image
# * Rate of dropout
# * Units of LSTM
# * Units of GRU

# %% [markdown]
# ## **What is the search space and what is the criteria to determine good/bad hyper-parameters?**

# %% [markdown]
# > * it is If we are solving a problem, we are usually looking for some solution which will be the best among others. The space of all feasible solutions (the set of solutions among which the desired solution resides). Each point in the search space represents one possible solution. Each possible solution can be "marked" by its value (or fitness) for the problem.
# * by using NAS. it is tune hyperparameters in neural network.

# %% [markdown]
# # **Implementation**

# %% [markdown]
# ## **Important Libraries**
# I will install a package and import several libraries.

# %%
# # install detect text language package
# !pip install langdetect
# # install google translate package
# !pip install googletrans==3.1.0a

# %%
# For uploading and accessing the data
import numpy as np
import pandas as pd


# used to work with Regular Expressions
import re
# for serializing and de-serializing a Python object structure.
import pickle
# provides a set of diverse algorithms for NLP
import nltk 
# Stemming maps different forms of the same word to a common
from nltk.stem.snowball import SnowballStemmer 
# used to find the words and punctuation in a string
from nltk.tokenize import word_tokenize
# does not add much meaning to a sentence.
from nltk.corpus import stopwords



# for Data Visualization
import matplotlib.pyplot as plt

# provides the python interpreter with image editing capabilities.
from PIL import Image
# used for creating Progress Meters or Progress Bars. 
from tqdm.notebook import tqdm

# import imageio as iio


# preprocess text data
from tensorflow.keras.preprocessing.text import Tokenizer
# used to ensure that all sequences in a list have the same length.
from tensorflow.keras.preprocessing.sequence import pad_sequences


# detect the language of text
from langdetect import detect

# For translate the values
from googletrans import Translator

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D, LSTM, BatchNormalization, MaxPooling2D, Dropout, Bidirectional, SpatialDropout2D
from tensorflow.keras.optimizers import Adam, Nadam
from tensorflow.keras import regularizers



# import warnings to prevent show warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **Function**
#  I will make functions to help me to reduce the code.

# %%
# Make Function to detect the language of text
def detect_langauge_text(text):
   try:
       return detect(text)
   except:
       return 'unknown'

# %%
# required package for tokenization.
nltk.download('punkt') 
nltk.download('stopwords')

# for stemming algorithm
stemmer = SnowballStemmer("english")
stop_words = set(stopwords.words("english"))


# Make Function to clean text
def clean_text(text, for_embedding=False):
    """ steps:
        - remove any html tags (< /br> often found)
        - Keep only ASCII + European Chars and whitespace, no digits
        - remove single letter chars
        - convert all whitespaces (tabs etc.) to single wspace
        if not for embedding (but e.g. tdf-idf):
        - all lowercase
        - remove stopwords, punctuation and stemm
        - return the clean text
    """
    re_wspace = re.compile(r"\s+", re.IGNORECASE)
    re_tags = re.compile(r"<[^>]+>")
    re_ASII = re.compile(r"[^A-Za-zÀ-ž ]", re.IGNORECASE)
    re_single_char = re.compile(r"\b[A-Za-zÀ-ž]\b", re.IGNORECASE)
    if for_embedding:
        # Keep punctuation
        re_ASII = re.compile(r"[^A-Za-zÀ-ž,.!? ]", re.IGNORECASE)
        re_single_char = re.compile(r"\b[A-Za-zÀ-ž,.!?]\b", re.IGNORECASE)

    text = re.sub(re_tags, " ", text)
    text = re.sub(re_ASII, " ", text)
    text = re.sub(re_single_char, " ", text)
    text = re.sub(re_wspace, " ", text)

    word_tokens = word_tokenize(text)
    words_tokens_lower = [word.lower() for word in word_tokens]

    if for_embedding:
        # no stemming, lowering and punctuation / stop words removal
        words_filtered = word_tokens
    else:
        words_filtered = [
            stemmer.stem(word) for word in words_tokens_lower if word not in stop_words
        ]

    text_clean = " ".join(words_filtered)
    return text_clean
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# Create function to preprocess image data
def load_image(file):
    try:
        image = Image.open(
            file
        ).convert('LA').resize((64, 64))
        arr = np.array(image)
    except:
        arr = np.zeros((64, 64, 2))
    return arr

# %%
# Function to preprocess to list of text
def _preprocess(list_of_text):
    return pad_sequences(
        tokenizer.texts_to_sequences(list_of_text),
        maxlen= max_len,
        padding='post',
    )

# %%
# dispay the result of the model 
def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

# %%
# Make a Function for predict the testing data and save it in the csv file
def predict_save_csv(search_model, classifier_name):
    
    # we can do prediction on training set
    y_predict = search_model.predict(
        {
            'summary': x_test_text,
            'image': x_test_image
        }
    )
    
    # probabilities
    price_predicted = y_predict['price']
    
    
    submission = pd.DataFrame()
    submission['id'] = df_test.index
    submission['price'] = np.argmax(price_predicted, axis=1)
    
    file_name = 'Compition_4' + classifier_name + '.csv'
    submission.to_csv(file_name, index=False)

# %% [markdown]
# ## **Reading the data and Quickly look it**
# First, I will download and unzip the dataset. Then i will read the data and show it. check the null value and drop it. I will detect langauges to the text and i will translate the text to english language.

# %%
# # # First let's download and unzip the dataset
# ! wget https://github.com/CISC-873/Information-2021/releases/download/data/a4.zip
# ! unzip -q a4.zip

# %%
# after unzipping the datset
# we find that (through the file browser on the left) there is a csv file and a folder of images
# reading the training dataset 
df_train = pd.read_csv('train_xy.csv') 
# reading the testing dataset 
df_test = pd.read_csv('test_x.csv', index_col= 'id')

# %%
# show the training data
df_train
# Out:
#                                                 summary               image  \
# 0     Spacious, sunny and cozy modern apartment in t...     img_train/0.jpg
# 1     Located in one of the most vibrant and accessi...     img_train/1.jpg
# 2     Logement coquet et douillet à 10 minutes du ce...     img_train/2.jpg
# 3     Beautiful and spacious (1076 sc ft, / 100 mc) ...     img_train/3.jpg
# 4     Très grand appartement ''rustique'' et très ag...     img_train/4.jpg
# ...                                                 ...                 ...
# 7622  Un grand logement 4 et 1/2, tout inclut, bien ...  img_train/7626.jpg
# 7623  Magnificent condo directly on the river. You w...  img_train/7627.jpg
# 7624  This apartment is perfect for anyone visiting ...  img_train/7628.jpg
# 7625  It is a cozy ,clean ,and comfortable apartment...  img_train/7629.jpg
# 7626  Modern country style (newly-renovated); open c...  img_train/7630.jpg
#
#            type  price
# 0     Apartment      1
# ...

# %%
# show the testing data
df_test
# Out:
#                                                 summary              image
# id
# 0     Charming warm house is ready to host you here ...     img_test/0.jpg
# 1     La chambre est spacieuse et lumineuse, dans un...     img_test/1.jpg
# 2     Grande chambre confortable située au sous-sol ...     img_test/2.jpg
# 3     Près d’un Métro, ligne orange. 10 minutes à pi...     img_test/3.jpg
# 4     Very bright appartment and very cosy. 2 separa...     img_test/4.jpg
# ...                                                 ...                ...
# 7626  Large, fully-furnished flat with brick walls a...  img_test/7627.jpg
# 7627  Logement situé dans le haut d’un duplex. Vivez...  img_test/7628.jpg
# 7628  My place is close to parks, . My place is good...  img_test/7629.jpg
# 7629  *** For security reasons, I will prioritize gu...  img_test/7630.jpg
# 7630  Stay in an amazing area of Montreal! 5-7 min f...  img_test/7631.jpg
#
# [7360 rows x 2 columns]

# %%
# check the data have the null values in training data
df_train.isna().sum()
# Out:
# summary    301
# image        0
# type         0
# price        0
# dtype: int64

# %%
# check the data have the null values in testing data
df_test.isna().sum()
# Out:
# summary    0
# image      0
# dtype: int64

# %%
# Drop the null value in training data 
df_train = df_train.dropna()

# %%
#show the training data
df_train
# Out:
#                                                 summary               image  \
# 0     Spacious, sunny and cozy modern apartment in t...     img_train/0.jpg
# 1     Located in one of the most vibrant and accessi...     img_train/1.jpg
# 2     Logement coquet et douillet à 10 minutes du ce...     img_train/2.jpg
# 3     Beautiful and spacious (1076 sc ft, / 100 mc) ...     img_train/3.jpg
# 4     Très grand appartement ''rustique'' et très ag...     img_train/4.jpg
# ...                                                 ...                 ...
# 7622  Un grand logement 4 et 1/2, tout inclut, bien ...  img_train/7626.jpg
# 7623  Magnificent condo directly on the river. You w...  img_train/7627.jpg
# 7624  This apartment is perfect for anyone visiting ...  img_train/7628.jpg
# 7625  It is a cozy ,clean ,and comfortable apartment...  img_train/7629.jpg
# 7626  Modern country style (newly-renovated); open c...  img_train/7630.jpg
#
#            type  price
# 0     Apartment      1
# ...

# %%
# check the language of text and get values and counts it in training data
df_train['summary'].apply(detect_langauge_text).value_counts()
# Out:
# en       5258
# fr       2034
# zh-cn      10
# de          6
# es          5
# ro          3
# ko          2
# af          2
# nl          1
# da          1
# pt          1
# vi          1
# fi          1
# id          1
# Name: summary, dtype: int64

# %%
# check the language of text and get values and counts it in training data
df_test['summary'].apply(detect_langauge_text).value_counts()
# Out:
# en         5266
# fr         2051
# zh-cn         9
# es            8
# de            4
# af            3
# ko            3
# nl            2
# vi            2
# it            2
# ro            2
# pt            2
# no            1
# et            1
# tl            1
# ca            1
# id            1
# unknown       1
# Name: summary, dtype: int64

# %%
# Translate the text to english language in training and testing data
translator = Translator()
df_train.summary = df_train.summary.apply(lambda x: translator.translate(x, dest='en').text)
df_test.summary = df_test.summary.apply(lambda x: translator.translate(x, dest='en').text)

# %%
#show the training data
df_train
# Out:
#                                                 summary               image  \
# 0     Spacious, sunny and cozy modern apartment in t...     img_train/0.jpg
# 1     Located in one of the most vibrant and accessi...     img_train/1.jpg
# 2     Pretty and cozy accommodation 10 minutes from ...     img_train/2.jpg
# 3     Beautiful and spacious (1076 sc ft, / 100 mc) ...     img_train/3.jpg
# 4     Very large ''rustic'' and very pleasant apartm...     img_train/4.jpg
# ...                                                 ...                 ...
# 7622  A large 4 and 1/2 apartment, all inclusive, we...  img_train/7626.jpg
# 7623  Magnificent condo directly on the river. You w...  img_train/7627.jpg
# 7624  This apartment is perfect for anyone visiting ...  img_train/7628.jpg
# 7625  It is a cozy ,clean ,and comfortable apartment...  img_train/7629.jpg
# 7626  Modern country style (newly-renovated); open c...  img_train/7630.jpg
#
#            type  price
# 0     Apartment      1
# ...

# %%
# Show the testing data
df_test
# Out:
#                                                 summary              image
# id
# 0     Charming warm house is ready to host you here ...     img_test/0.jpg
# 1     The room is spacious and bright, in an apartme...     img_test/1.jpg
# 2     Large comfortable room located in the basement...     img_test/2.jpg
# 3     Near a Metro, orange line. 10 minutes walking....     img_test/3.jpg
# 4     Very bright appartment and very cosy. 2 separa...     img_test/4.jpg
# ...                                                 ...                ...
# 7626  Large, fully-furnished flat with brick walls a...  img_test/7627.jpg
# 7627  Accommodation located at the top of a duplex. ...  img_test/7628.jpg
# 7628  My place is close to parks, . My place is good...  img_test/7629.jpg
# 7629  *** For security reasons, I will prioritize gu...  img_test/7630.jpg
# 7630  Stay in an amazing area of Montreal! 5-7 min f...  img_test/7631.jpg
#
# [7360 rows x 2 columns]

# %% [markdown]
# ## **Data Preprocessing**
# I will clean the training and testing data.
#
# We have image and text data.
#
# - Image data: resize, convert image to gray scale  and show the some of image.
# - Text data: tokenization and converting to integer IDs

# %%
# %%time
# Clean texts training data 
df_train["summary_clean"] = df_train.loc[df_train["summary"].str.len() > 0, "summary"] # get all text data the length it greater than 0 in training data
# call clean_text of method to apply it on text_clean feature in traing data
df_train["summary_clean"] = df_train["summary_clean"].map(
    lambda x: clean_text(x, for_embedding=False) if isinstance(x, str) else x  # check if text is instance of string
)
# Out:
# CPU times: user 6.72 s, sys: 33 ms, total: 6.75 s
# Wall time: 6.76 s

# %%
# %%time
# Clean texts training data 
df_test["summary_clean"] = df_test.loc[df_test["summary"].str.len() > 0, "summary"] # get all text data the length it greater than 0 in training data
# call clean_text of method to apply it on text_clean feature in traing data
df_test["summary_clean"] = df_test["summary_clean"].map(
    lambda x: clean_text(x, for_embedding=False) if isinstance(x, str) else x  # check if text is instance of string
)
# Out:
# CPU times: user 6.64 s, sys: 27 ms, total: 6.66 s
# Wall time: 6.67 s

# %%
#show the training data
df_train
# Out:
#                                                 summary               image  \
# 0     Spacious, sunny and cozy modern apartment in t...     img_train/0.jpg
# 1     Located in one of the most vibrant and accessi...     img_train/1.jpg
# 2     Pretty and cozy accommodation 10 minutes from ...     img_train/2.jpg
# 3     Beautiful and spacious (1076 sc ft, / 100 mc) ...     img_train/3.jpg
# 4     Very large ''rustic'' and very pleasant apartm...     img_train/4.jpg
# ...                                                 ...                 ...
# 7622  A large 4 and 1/2 apartment, all inclusive, we...  img_train/7626.jpg
# 7623  Magnificent condo directly on the river. You w...  img_train/7627.jpg
# 7624  This apartment is perfect for anyone visiting ...  img_train/7628.jpg
# 7625  It is a cozy ,clean ,and comfortable apartment...  img_train/7629.jpg
# 7626  Modern country style (newly-renovated); open c...  img_train/7630.jpg
#
# ...

# %%
# Show the testing data
df_test
# Out:
#                                                 summary              image  \
# id
# 0     Charming warm house is ready to host you here ...     img_test/0.jpg
# 1     The room is spacious and bright, in an apartme...     img_test/1.jpg
# 2     Large comfortable room located in the basement...     img_test/2.jpg
# 3     Near a Metro, orange line. 10 minutes walking....     img_test/3.jpg
# 4     Very bright appartment and very cosy. 2 separa...     img_test/4.jpg
# ...                                                 ...                ...
# 7626  Large, fully-furnished flat with brick walls a...  img_test/7627.jpg
# 7627  Accommodation located at the top of a duplex. ...  img_test/7628.jpg
# 7628  My place is close to parks, . My place is good...  img_test/7629.jpg
# 7629  *** For security reasons, I will prioritize gu...  img_test/7630.jpg
# 7630  Stay in an amazing area of Montreal! 5-7 min f...  img_test/7631.jpg
#
#                                           summary_clean
# id
# ...

# %%
# convert the data type of type from object to catecory and encode it 
df_train['type'] = df_train['type'].astype('category').cat.codes
# Show the type feature
df_train['type']
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 7622     1
# 7623     1
# 7624     1
# 7625     1
# 7626    17
# Name: type, Length: 7326, dtype: int8

# %%
# loading images:
x_train_image = np.array([load_image(i) for i in tqdm(df_train.image)])

# loading summary_clean: (force convert some of the non-string cell to string)
x_train_text = df_train['summary_clean'].astype('str')
# Out:
#   0%|          | 0/7326 [00:00<?, ?it/s]

# %%
image = Image.open(
            'img_train/0.jpg'
        ).convert('LA').resize((64, 64))
image
# Out:
# <PIL.Image.Image image mode=LA size=64x64 at 0x7FBEF664B3D0>

# %%
# check image loading
plt.imshow(x_train_image[0, :, :, 0])

# %%
# Display the image of shape in teaining data 
x_train_image.shape
# Out:
# (7326, 64, 64, 2)

# %%
# Set values
num_words = 100000
max_len = 400

# %%
# build vocabulary from training set
tokenizer = Tokenizer(num_words = num_words)
tokenizer.fit_on_texts(x_train_text)

# %%
# padding is done inside: 
x_train_text_id = _preprocess(x_train_text)

# %%
# Show the shape of summary of training data
x_train_text_id.shape
# Out:
# (7326, 400)

# %%
# we can use the tokenizer to convert IDs to words.
tokenizer.sequences_to_texts(x_train_text_id[:1])
# Out:
# ['spacious sunni cozi modern apart heart montreal bedroom central locat popular plateau mont royal neighborhood middl princ arthur pedestrian street close amen restaur coffe hous bar club shop univers subway station experi montreal like real local resid heart action grand prix week grill saint laurent festiv mural much']

# %%
#show the count value in graph of price in trining data
df_train.price.value_counts().plot.bar()

# %%
#show the count value in graph of type in trining data
df_train['type'].value_counts().plot.bar()

# %%
# set the length of type and price in training and testing data
len_type = len(df_train['type'].unique())
len_price = len(df_train.price.unique())

# %%
# loading images:
x_test_image = np.array([load_image(i) for i in tqdm(df_test.image)])

# loading overview: (force convert some of the non-string cell to string)
x_test_text = _preprocess(df_test['summary_clean'].astype('str'))
# Out:
#   0%|          | 0/7360 [00:00<?, ?it/s]

# %% [markdown]
# ## **Different Trials**

# %% [markdown]
# ### **6* Convolutional Layer with Embedding layer**
#
# **Convolutional layers** are the layers where filters are applied to the original image, or to other feature maps in a deep CNN. This is where most of the user-specified parameters are in the network. The most important parameters are the number of kernels and the size of the kernels.
#
# Conv2D is a 2D Convolution Layer, this layer creates a convolution kernel that is wind with layers input which helps produce a tensor of outputs.
#
# Embedding layer enables us to convert each word into a fixed length vector of defined size. The resultant vector is a dense one with having real values instead of just 0's and 1's. The fixed length of word vectors helps us to represent words in a better way along with reduced dimensions.
#
# \
#
# **Embedding layer** enables us to convert each word into a fixed length vector of defined size. The resultant vector is a dense one with having real values instead of just 0's and 1's. The fixed length of word vectors helps us to represent words in a better way along with reduced dimensions.
#
# Embeddings make it easier to do on large inputs like sparse vectors representing words.

# %% [markdown]
# **The Conv2D class constructor has the following arguments:**
# * Filters:
#   * Mandatory Conv2D parameter is the numbers of filters that convolutional layers will learn from. It is an integer value and also determines the number of output filters in the convolution.
# * Kernel_size:
#   * This parameter determines the dimensions of the kernel.
#   * It is an integer or tuple/list of 2 integers, specifying the height and width of the 2D convolution window.
#   * This parameter must be an odd integer
# * Strides:
#   * This parameter is an integer or tuple/list of 2 integers, specifying the “step” of the convolution along with the height and width of the input volume.
# * Padding:
#   * The padding parameter of the Keras Conv2D class can take one of two values: ‘valid’ or ‘same’.
#   * Setting the value to “valid” parameter means that the input volume is not zero-padded and the spatial dimensions are allowed to reduce via the natural application of convolution.
# * Activation:
#   * The activation parameter to the Conv2D class is simply a convenience parameter which allows you to supply a string, which specifies the name of the activation function you want to apply after performing the convolution.
# * Kernel_initializer:
#   * This parameter controls the initialization method which is used to initialize all the values in the Conv2D class before actually training the model.
#   * It is the initializer for the kernel weights matrix.
# * Kernel_regularizer:
#   * it is the Regularizer function which is applied to the kernel weights matrix.
#
#
# \
#
# \
#
#
#
#
#
#
#
# **The Embedding class constructor has the following arguments:**
# * Input_dim:
#   * it is Integer. Size of the vocabulary, i.e. maximum integer index + 1.
# * Output_dim:
#   * it is Integer. Dimension of the dense embedding.
# * Embeddings_initializer:
#   * it is Initializer for the embeddings matrix (see keras.initializers).
# * Embeddings_regularizer:
#   * Regularizer function applied to the embeddings matrix (see keras.regularizers).
#
#
# \
#
#
# Regularizations are techniques used to reduce the error by fitting a function appropriately on the given training set and avoid overfitting.
#
# There are two types of regularization: L1 and L2 regularization, both are used to reduce overfitting of our model.

# %% [markdown]
# #### **1* Convolutional Layer with Embedding layer, Multi-modality and Multi-task**

# %% [markdown]
# **Expectations:**
#
# I Will use CNN because CNNs are very effective in reducing the number of parameters without losing on the quality of models and i will used for image processing, classification, segmentation and also for other auto correlated data.
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu

# %%
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
averaged = tf.reduce_mean(embedded, axis=1)


# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)


cov = Conv2D(32, (2, 2))(pl)
pl = MaxPool2D((2, 2))(cov)

flattened = Flatten()(pl)


# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=10, )
    ],
    verbose=1
)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_4 (InputLayer)           [(None, 64, 64, 2)]  0           []
#
#  conv2d_2 (Conv2D)              (None, 49, 49, 32)   16416       ['input_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 3, 3, 32)    0           ['conv2d_2[0][0]']
#
#  input_3 (InputLayer)           [(None, 400)]        0           []
#
#  conv2d_3 (Conv2D)              (None, 2, 2, 32)     4128        ['max_pooling2d_2[0][0]']
#
#  embedding_1 (Embedding)        (None, 400, 400)     40000000    ['input_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 32)    0           ['conv2d_3[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 400)         0           ['embedding_1[0][0]']
#  bda)
#
#  flatten_1 (Flatten)            (None, 32)           0           ['max_pooling2d_3[0][0]']
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
# The best hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#
#
# ```
#  In Colab ==> Score: 0.6808
#
#  In Kaggle
#     * Public score: 0.69456
#     * Private score: 0.67201
#
# ```
#
# **The reasons for the observed result:**
#
# We can see from the graph that the loss is lowering and the accuracy is improving until the model was forced to halt due to overfitting.
#
#
# \
#
# \
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
# The rule of dimension image: ((size of image - size of filter + 2 * padding) / stride) +1
#
#
# \
#
#
# So, In the frist layer is ((64-16) +1) = 49 (49 x 49) and so on.
#
#
# \
#
#
#
# \
#
# **Plan:**
#
# I will use the Convolutional layer with Dropout

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_1_651')

# %% [markdown]
# #### **1* Convolutional layer with Dropout**
#
# Dropout is a technique used to prevent a model from overfitting. Dropout works by randomly setting the outgoing edges of hidden units (neurons that make up hidden layers) to 0 at each update of the training phase.

# %% [markdown]
# Dropout layer has the following arguments:
# * Rate: Float between 0 and 1. Fraction of the input units to drop.
# * Seed: A Python integer to use as random seed.
# * Inputs: Input tensor (of any rank).

# %% [markdown]
# **Expectations:**
#
# I Will used to prevent overfitting on the training data and it will train well.
#
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.1
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.1

# %%
# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
averaged = tf.reduce_mean(embedded, axis=1)


# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
# batch_norm = BatchNormalization()(cov)
pl = MaxPool2D((16, 16))(cov)

dropout1 = Dropout(0.1)(pl)

cov = Conv2D(64, (2, 2))(dropout1)
# batch_norm = BatchNormalization()(cov)
pl = MaxPool2D((2, 2))(cov)

dropout2 = Dropout(0.1)(pl)


# cov = Conv2D(128, (3, 3))(dropout1)
# batch_norm = BatchNormalization()(cov)
# pl = MaxPool2D((3, 3))(batch_norm)

# dropout2 = Dropout(0.15)(pl)

flattened = Flatten()(dropout2)


# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=10, )
    ],
    verbose=1
)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_12 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_12 (Conv2D)             (None, 49, 49, 32)   16416       ['input_12[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_12[0][0]']
#  )
#
#  dropout_10 (Dropout)           (None, 3, 3, 32)     0           ['max_pooling2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 2, 2, 64)     8256        ['dropout_10[0][0]']
#
#  input_11 (InputLayer)          [(None, 400)]        0           []
#
#  max_pooling2d_13 (MaxPooling2D  (None, 1, 1, 64)    0           ['conv2d_13[0][0]']
#  )
#
#  embedding_5 (Embedding)        (None, 400, 400)     40000000    ['input_11[0][0]']
#
#  dropout_11 (Dropout)           (None, 1, 1, 64)     0           ['max_pooling2d_13[0][0]']
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.1
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.1
#
#
#
#
#
# ```
#  In Colab ==> Score: 0.6698
#
#  In Kaggle
#     * Public score: 0.68152
#     * Private score: 0.68722
#
# ```
#
# \
#
#
# **The reasons for the observed result:**
#
# we realize from the graph the loss is decreasing and the accuarcy is increasing until the model stopped by early stopping becuase it predicted in overfitting.
#
# \
#
# \
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
# The rule of dimension image: ((size of image - size of filter + 2 * padding) / stride) +1
# * Dropout: works by randomly setting the outgoing edges of hidden units.
#
#
#
# \
#
# **Plan:**
# I will use the Convolutional layer with LSTM Layer.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_2_651')

# %% [markdown]
# #### **1* LSTM layer**
#
# Long Short-Term Memory (LSTM) networks are a type of recurrent neural network capable of learning order dependence in sequence prediction problems. it is quite effective in predicting the long sequences of data like sentences and stock prices over a period of time. It also includes a special unit known as a memory cell to withhold the past information for a longer time for making an effective prediction. LSTM with its memory cells is an improved version of traditional RNNs which cannot predict using such a long sequence of data and run into the problem of vanishing gradient. LSTM are introducing more & more controlling knobs, which control the flow and mixing of Inputs as per trained Weights.

# %% [markdown]
# LSTM layer has the following arguments:
# * Units: Positive integer, dimensionality of the output space.
# * Activation: Activation function to use. Default: hyperbolic tangent (tanh).
# * Kernel_initializer: Initializer for the kernel weights matrix, used for the linear transformation of the inputs. Default: "glorot_uniform".
# * Kernel_regularizer: Regularizer function applied to the kernel weights matrix. Default: None.
# * Bias_regularizer: Regularizer function applied to the bias vector. Default: None.

# %% [markdown]
# **Expectations:**
#
# I Will used to makes the model deeper, more accurately earning the description as a deep learning technique. And bringing in more flexibility in controlling the outputs.
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of LSTM: 256
# * Kernel_regularizer: L2(0.01)
# * Recurrent_regularizer: l2(0.01)
# * bias_regularizer: l2(0.01)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
# \

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import collections
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPool2D,LSTM, GRU, Bidirectional
from tensorflow.keras.optimizers import Adam


# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
lstm = LSTM(256, activation='tanh', kernel_regularizer=regularizers.l2(0.01), recurrent_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01))(embedded)
# lstm = LSTM(64, kernel_regularizer=regularizers.l2(0.02), recurrent_regularizer=regularizers.l2(0.02), bias_regularizer=regularizers.l2(0.01))(lstm)

# averaged = tf.reduce_mean(embedded, axis=1)





# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)

dropout1 = Dropout(0.2)(pl)


cov = Conv2D(32, (2, 2))(dropout1)
pl = MaxPool2D((2, 2))(cov)


dropout2 = Dropout(0.2)(pl)

flattened = Flatten()(dropout2)


# fusion - combinig both
fused = tf.concat([lstm, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0,
        'price': 1,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=10, )
    ],
    verbose=1
)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_10 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_8 (Conv2D)              (None, 49, 49, 32)   16416       ['input_10[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 32)    0           ['conv2d_8[0][0]']
#
#  dropout_2 (Dropout)            (None, 3, 3, 32)     0           ['max_pooling2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 2, 2, 32)     4128        ['dropout_2[0][0]']
#
#  input_9 (InputLayer)           [(None, 400)]        0           []
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 1, 1, 32)    0           ['conv2d_9[0][0]']
#
#  embedding_4 (Embedding)        (None, 400, 400)     40000000    ['input_9[0][0]']
#
#  dropout_3 (Dropout)            (None, 1, 1, 32)     0           ['max_pooling2d_9[0][0]']
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of LSTM: 256
# * Kernel_regularizer: L2(0.01)
# * Recurrent_regularizer: l2(0.01)
# * bias_regularizer: l2(0.01)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
#
#
# ```
#  In Colab ==> Score: 0.6241
#
#  In Kaggle
#     * Public score: 0.62038
#     * Private score: 0.62934
#
# ```
#
# **The reasons for the observed result:**
# We can see from the graph that the loss is lowering and the accuracy is growing until the model stops early because it predicted overfitting.
#
# \
#
# \
#
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
#
#
#
#
# \
#
# **Plan:**
# I will use the Convolutional layer with GRU Layer.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_3_651')

# %% [markdown]
# #### **1* GRU layer**
#
# Gated recurrent units (GRUs) are a gating mechanism in recurrent neural networks, like a long short-term memory (LSTM) with a forget gate, but has fewer parameters than LSTM, as it lacks an output gate. it intends to use connections through a sequence of nodes to perform machine learning tasks associated with memory and clustering, for instance, in speech recognition. GRU supports gating and a hidden state to control the flow of information. To solve the problem that comes up in RNN, GRU uses two gates: the update gate and the reset gate. GRU use less training parameters and therefore use less memory, execute faster and train faster than LSTM's.

# %% [markdown]
# GRU layer has the following arguments:
# * Units: Positive integer, dimensionality of the output space.
# * Activation: Activation function to use. Default: hyperbolic tangent (tanh).
# * Kernel_initializer: Initializer for the kernel weights matrix, used for the linear transformation of the inputs. Default: "glorot_uniform".
# * Kernel_regularizer: Regularizer function applied to the kernel weights matrix. Default: None.
# * Bias_regularizer: Regularizer function applied to the bias vector. Default: None.

# %% [markdown]
# **Expectations:**
#
# I Will used to solve the vanishing gradient problem faced by standard recurrent neural networks (RNN). GRU shares many properties of long short-term memory (LSTM).
#
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of GRU: 256
# * Kernel_regularizer: L2(0.01)
# * Recurrent_regularizer: l2(0.01)
# * bias_regularizer: l2(0.01)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2

# %%
# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
gru = GRU(512 ,kernel_regularizer=regularizers.l2(0.01), recurrent_regularizer=regularizers.l2(0.01), bias_regularizer=regularizers.l2(0.01))(embedded)
# gru = GRU(512, kernel_regularizer=regularizers.l2(0.02), recurrent_regularizer=regularizers.l2(0.02), bias_regularizer=regularizers.l2(0.02))(gru)

# averaged = tf.reduce_mean(embedded, axis=1)





# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)

dropout1 = Dropout(0.2)(pl)


cov = Conv2D(32, (2, 2))(dropout1)
pl = MaxPool2D((2, 2))(cov)


dropout2 = Dropout(0.2)(pl)

flattened = Flatten()(dropout2)


# fusion - combinig both
fused = tf.concat([gru, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=10, )
    ],
    verbose=1
)
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_12 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_10 (Conv2D)             (None, 49, 49, 32)   16416       ['input_12[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_10[0][0]']
#  )
#
#  dropout_4 (Dropout)            (None, 3, 3, 32)     0           ['max_pooling2d_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 2, 2, 32)     4128        ['dropout_4[0][0]']
#
#  input_11 (InputLayer)          [(None, 400)]        0           []
#
#  max_pooling2d_11 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_11[0][0]']
#  )
#
#  embedding_5 (Embedding)        (None, 400, 400)     40000000    ['input_11[0][0]']
#
#  dropout_5 (Dropout)            (None, 1, 1, 32)     0           ['max_pooling2d_11[0][0]']
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of GRU: 256
# * Kernel_regularizer: L2(0.01)
# * Recurrent_regularizer: l2(0.01)
# * bias_regularizer: l2(0.01)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
#
#
# ```
#  In Colab ==> Score: 0.6241
#
#  In Kaggle
#     * Public score: 0.62038
#     * Private score: 0.62934
#
# ```
#
# **The reasons for the observed result:**
#
# we realize from the graph the loss is decreasing and the accuracy is decrease and increasing until the model stopped by early stopping becuase it predicted in overfitting.
#
# \
#
# \
#
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
#
#
#
#
# \
#
#
# **Plan:**
# I will use the Convolutional layer with BiDirectional layer.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_4_651')

# %% [markdown]
# #### **1* BiDirectional layer**
#
# Bidirectional recurrent neural networks (BRNN) connect two hidden layers of opposite directions to the same output. With this form of generative deep learning, the output layer can get information from past (backwards) and future (forward) states simultaneously. It consists of training an undirected neural network to map input to output and vice-versa.

# %% [markdown]
# Bidirectional layer has the following arguments:
# * Layer: keras.layers.RNN instance, such as keras.layers.LSTM or keras.layers.GRU.
# * Merge_mode: Mode by which outputs of the forward and backward RNNs will be combined. One of {'sum', 'mul', 'concat', 'ave', None}.

# %% [markdown]
# **Expectations:**
#
# I Will used to connect two hidden layers of opposite directions to the same output.
#
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of GRU: 256
# * Kernel_regularizer: L2(0.02)
# * Recurrent_regularizer: l2(0.02)
# * bias_regularizer: l2(0.02)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2

# %%
# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
bidir = Bidirectional(GRU(64 ,kernel_regularizer=regularizers.l2(0.02), recurrent_regularizer=regularizers.l2(0.02), bias_regularizer=regularizers.l2(0.02)))(embedded)

# averaged = tf.reduce_mean(embedded, axis=1)





# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16))(in_image)
pl = MaxPool2D((16, 16))(cov)

dropout1 = Dropout(0.2)(pl)


cov = Conv2D(32, (2, 2))(dropout1)
pl = MaxPool2D((2, 2))(cov)


dropout2 = Dropout(0.2)(pl)

flattened = Flatten()(dropout2)


# fusion - combinig both
fused = tf.concat([bidir, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Adam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=50,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=10, )
    ],
    verbose=1
)
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_14 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_12 (Conv2D)             (None, 49, 49, 32)   16416       ['input_14[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 3, 3, 32)    0           ['conv2d_12[0][0]']
#  )
#
#  dropout_6 (Dropout)            (None, 3, 3, 32)     0           ['max_pooling2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 2, 2, 32)     4128        ['dropout_6[0][0]']
#
#  input_13 (InputLayer)          [(None, 400)]        0           []
#
#  max_pooling2d_13 (MaxPooling2D  (None, 1, 1, 32)    0           ['conv2d_13[0][0]']
#  )
#
#  embedding_6 (Embedding)        (None, 400, 400)     40000000    ['input_13[0][0]']
#
#  dropout_7 (Dropout)            (None, 1, 1, 32)     0           ['max_pooling2d_13[0][0]']
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 50.
# * batch_size: 16
# * Patience: 10
# * Unit of GRU: 256
# * Kernel_regularizer: L2(0.01)
# * Recurrent_regularizer: l2(0.01)
# * bias_regularizer: l2(0.01)
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
#
#
# ```
#  In Colab ==> Score: 0.6310
#
#  In Kaggle
#     * Public score: 0.61576
#     * Private score: 0.62826
#
# ```
#
# **The reasons for the observed result:**
#
# we realize from the graph the loss is decreasing and the accuracy is increasing until the model stopped by early stopping becuase it predicted in overfitting.
#
# \
#
# \
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
#
#
#
# \
#
# **Plan:**
# I will use the Convolutional layer with Multi-task.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_5_651')

# %% [markdown]
# #### **1* Convolutional Layer without Multi-task**
#
# it aims to solve multiple different tasks at the same time, by taking advantage of the similarities between different tasks. This can improve the learning efficiency and also act as a regularizer.
# Such approaches offer advantages like improved data efficiency, reduced overfitting through shared representations, and fast learning by leveraging auxiliary information.

# %% [markdown]
# **Expectations:**
#
# I Will used to multi-task because i have 2 output:
# * type: it is text.
# * price: it is number.
#
#
#
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 30.
# * batch_size: 16
# * Patience: 5
#
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2

# %%
# here we have two inputs. one for image and the other for text.
in_text = keras.Input(batch_shape=(None, max_len))
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# text part
# simple average of embedding. you can change it to anything else as needed
embedded = keras.layers.Embedding(tokenizer.num_words, 400)(in_text)
averaged = tf.reduce_mean(embedded, axis=1)


# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (16, 16),strides=(1,1), padding='same', activation='relu')(in_image)
batch_norm = BatchNormalization()(cov)
pl = MaxPool2D((16, 16),strides=(1,1))(batch_norm)

dropout1 = Dropout(0.2)(pl)




cov = Conv2D(64, (2, 2),strides=(1,1), padding='same', activation='relu')(dropout1)
batch_norm = BatchNormalization()(cov)

pl = MaxPool2D((2, 2),strides=(1,1))(batch_norm)

dropout1 = Dropout(0.2)(pl)


flattened = Flatten()(dropout1)

# fusion - combinig both
fused = tf.concat([averaged, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
# p_type = Dense(len_type, activation='softmax', name='type')(fused)
p_price = Dense(len_price, activation='softmax', name='price')(fused)


# define model input/output using keys.
model = keras.Model(
    inputs={
        'summary': in_text,
        'image': in_image
    },
    outputs={
        # 'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Nadam(),
    loss={
        # 'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        # 'type': 0.5,
        'price': 1,       
    },
    metrics={
        # 'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        # 'type': df_train['type'],
        'price': df_train.price
    },
    epochs=30,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, )
    ],
    verbose=1
)
# Out:
# Model: "model_12"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_26 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 32)   16416       ['input_26[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 32)  128         ['conv2d_28[0][0]']
#  ormalization)
#
#  max_pooling2d_28 (MaxPooling2D  (None, 49, 49, 32)  0           ['batch_normalization_14[0][0]']
#  )
#
#  dropout_22 (Dropout)           (None, 49, 49, 32)   0           ['max_pooling2d_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 49, 49, 64)   8256        ['dropout_22[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 49, 49, 64)  256         ['conv2d_29[0][0]']
#  ormalization)
#
#  input_25 (InputLayer)          [(None, 400)]        0           []
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 30.
# * batch_size: 16
# * Patience: 5
#
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (16, 16)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 32
#   * Kernel_size: (2, 2)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
# \
#
# **The reasons for the observed result:**
#
# We can see from the graph that the loss is reducing and increasing, while the accuracy is decreasing and increasing, until the model was forced to end early due to overfitting.
#
# \
#
# \
#
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.
#
#
#
# \
#
#
#
#
# **Plan:**
# I will use the Convolutional Layers without Multi-modality.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_6_651')

# %% [markdown]
# #### **1* Convolutional Layers without Multi-modality**

# %%
# here we have two inputs. one for image and the other for text.
in_image = keras.Input(batch_shape=(None, 64, 64, 2))

# image part 
# simple conv2d. you can change it to anything else as needed
cov = Conv2D(32, (3, 3),strides=(1,1), padding='same', activation='relu')(in_image)
batch_norm = BatchNormalization()(cov)
pl = MaxPool2D((3, 3),strides=(1,1))(batch_norm)

dropout1 = Dropout(0.2)(pl)


cov = Conv2D(64, (5, 5),strides=(1,1), padding='same', activation='relu')(dropout1)
batch_norm = BatchNormalization()(cov)
pl = MaxPool2D((5, 5),strides=(1,1))(batch_norm)

dropout1 = Dropout(0.2)(pl)


cov = Conv2D(128, (7, 7),strides=(1,1), padding='same', activation='relu')(dropout1)
batch_norm = BatchNormalization()(cov)

pl = MaxPool2D((7, 7),strides=(1,1))(batch_norm)

dropout1 = Dropout(0.2)(pl)





# cov = Conv2D(512, (, 11),strides=(1,1), padding='same', activation='relu')(dropout1)
# batch_norm = BatchNormalization()(cov)

# pl = MaxPool2D((2, 2),strides=(1,1))(batch_norm)

# dropout1 = Dropout(0.2)(pl)


flattened = Flatten()(dropout1)

# fusion - combinig both
# fused = tf.concat([averaged, flattened], axis=-1)

# multi-task learning (each is a multi-class classification)
# one dense layer for each task
p_type = Dense(len_type, activation='softmax', name='type')(flattened)
p_price = Dense(len_price, activation='softmax', name='price')(flattened)


# define model input/output using keys.
model = keras.Model(
    inputs={
        # 'summary': in_text,
        'image': in_image
    },
    outputs={
        'type': p_type,
        'price': p_price,
    },
)



# compile model with optimizer, loss values for each task, loss 
# weights for each task.
model.compile(
    optimizer=Nadam(),
    loss={
        'type': 'sparse_categorical_crossentropy',
        'price': 'sparse_categorical_crossentropy',
    },
    loss_weights={
        'type': 0.5,
        'price': 0.5,       
    },
    metrics={
        'type': ['SparseCategoricalAccuracy'],
        'price': ['SparseCategoricalAccuracy'],
    },
)

# show the summary of the architecture model
print(model.summary())



# train the model
history = model.fit(
    x={
        # 'summary': x_train_text_id,
        'image': x_train_image
    },
    y={
        'type': df_train['type'],
        'price': df_train.price
    },
    epochs=25,
    batch_size=16,
    validation_split=0.2,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(monitor='val_price_loss', patience=5, )
    ],
    verbose=1
)
# Out:
# Model: "model_15"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_29 (InputLayer)          [(None, 64, 64, 2)]  0           []
#
#  conv2d_38 (Conv2D)             (None, 64, 64, 32)   608         ['input_29[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 64, 64, 32)  128         ['conv2d_38[0][0]']
#  ormalization)
#
#  max_pooling2d_38 (MaxPooling2D  (None, 62, 62, 32)  0           ['batch_normalization_24[0][0]']
#  )
#
#  dropout_32 (Dropout)           (None, 62, 62, 32)   0           ['max_pooling2d_38[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 62, 62, 64)   51264       ['dropout_32[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 62, 62, 64)  256         ['conv2d_39[0][0]']
#  ormalization)
#
#  max_pooling2d_39 (MaxPooling2D  (None, 58, 58, 64)  0           ['batch_normalization_25[0][0]']
#  )
#
# ...

# %%
# display the lass and val_loss from training model 
plot_graphs(history, "loss")
# display the price_Accuracy and val_price_Accuracy from training model 
plot_graphs(history, "price_sparse_categorical_accuracy")

# %% [markdown]
# **observations:**
#
# The hyperparameters for this model will be:
# * Input_dim: (None, 100000)
# * Output_dim: (None, 400)
# * Epochs: 25.
# * batch_size: 16
# * Patience: 5
#
#
#
# * In the first layer of image:
#   * Filters: 32
#   * Kernel_size: (3, 3)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
# * In the secound layer of image:
#   * Filters: 64
#   * Kernel_size: (5, 5)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
# * In the third layer of image:
#   * Filters: 128
#   * Kernel_size: (7, 7)
#   * Strides: (1, 1)
#   * Padding: same
#   * Activation: relu
#   * Dropout: 0.2
#
# \
#
# **The reasons for the observed result:**
#
# We can see from the graph that the loss is reducing and increasing, while the accuracy is decreasing and increasing, until the model was forced to end early due to overfitting.
#
# \
#
# \
#
#
# * Filters:
#   * Two key hyperparameters that define the convolution operation are size and number of kernels .
#   * it determines the depth of output feature.
# * Kernel_size:
#   * specifying the length of the convolution window.
# * Strides:
#   * Stride is the number of pixels shifts over the input matrix.
# * Padding:
#   * tries to pad evenly left and right, but if the amount of columns to be added is odd, it will add the extra column to the right, as is the case in this example (the same logic applies vertically: there may be an extra row of zeros at the bottom).
#   * With "same" padding, if you use a stride of 1, the layer's outputs will have the same spatial dimensions as its inputs.

# %%
# we can do prediction on testing set using the predict_save_csv function and it will predict the testing data and save it in the csv file
predict_save_csv(model, '_Model_433333333333_651')

# %% [markdown]
# # **Resources**

# %% [markdown]
# - https://www.quora.com/How-does-LSTM-help-prevent-the-vanishing-and-exploding-gradient-problem-in-a-recurrent-neural-network
# - https://www.geeksforgeeks.org/introduction-to-multi-task-learningmtl-for-deep-learning/
# - https://arxiv.org/abs/2009.09796
# - https://towardsdatascience.com/performance-comparison-catboost-vs-xgboost-and-catboost-vs-lightgbm-886c1c96db64
# - http://multicomp.cs.cmu.edu/multimodal-machine-learning/
# - https://towardsdatascience.com/catboost-vs-light-gbm-vs-xgboost-5f93620723db
